# %%
import pandas as pd

# %%
courses_df = pd.read_csv("class_data.csv")

# %%
courses_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CRN               148 non-null    int64
#  1   Subject           148 non-null    object
#  2   COURSE            148 non-null    int64
#  3   TITLE             148 non-null    object
#  4   COHORT            12 non-null     object
#  5   TYPE              77 non-null     object
#  6   SCHEDULE          104 non-null    object
#  7   TIME IN           102 non-null    object
#  8   TIME OUT          104 non-null    object
#  9   PLATFORM          127 non-null    object
#  10  INSTRUCTOR        148 non-null    object
#  11  INSTRUCTOR EMAIL  148 non-null    object
# dtypes: int64(2), object(10)
# memory usage: 14.0+ KB

# %%
courses_df.head()
# Out:
#      CRN Subject  COURSE               TITLE COHORT TYPE SCHEDULE   TIME IN  \
# 0  30151    BIOL     215  Organismal Biology    NaN  NaN     M, W  11:10 AM
# 1  30151    BIOL     215  Organismal Biology    NaN  NaN     M, W   2:10 PM
# 2  41373    BIOL     215  Organismal Biology    NaN  NaN     M, W  11:10 AM
# 3  41373    BIOL     215  Organismal Biology    NaN  NaN    T, Th   9:10 AM
# 4  48398    BIOL     215  Organismal Biology    NaN  NaN     M, W  11:10 AM
#
#    TIME OUT PLATFORM INSTRUCTOR INSTRUCTOR EMAIL
# 0  12:25 PM     4148    Song, M  songm@smccd.edu
# 1   5:00 PM     7241    Song, M  songm@smccd.edu
# 2  12:25 PM     4148    Song, M  songm@smccd.edu
# 3  11:50 AM     7241    Song, M  songm@smccd.edu
# 4  12:25 PM     4148    Song, M  songm@smccd.edu

# %%
courses_df = courses_df.drop_duplicates(subset="CRN")

# %%
courses_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 91 entries, 0 to 147
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CRN               91 non-null     int64
#  1   Subject           91 non-null     object
#  2   COURSE            91 non-null     int64
#  3   TITLE             91 non-null     object
#  4   COHORT            8 non-null      object
#  5   TYPE              43 non-null     object
#  6   SCHEDULE          70 non-null     object
#  7   TIME IN           68 non-null     object
#  8   TIME OUT          68 non-null     object
#  9   PLATFORM          85 non-null     object
#  10  INSTRUCTOR        91 non-null     object
#  11  INSTRUCTOR EMAIL  91 non-null     object
# dtypes: int64(2), object(10)
# memory usage: 9.2+ KB

# %%
courses_df.head()
# Out:
#      CRN Subject  COURSE                         TITLE COHORT TYPE SCHEDULE  \
# 0  30151    BIOL     215            Organismal Biology    NaN  NaN     M, W
# 2  41373    BIOL     215            Organismal Biology    NaN  NaN     M, W
# 4  48398    BIOL     215            Organismal Biology    NaN  NaN     M, W
# 6  48537    BIOL     230  Introduction to Cell Biology    NaN  NaN     M, W
# 8  48811    BIOL     230  Introduction to Cell Biology    NaN  NaN     M, W
#
#     TIME IN  TIME OUT PLATFORM INSTRUCTOR INSTRUCTOR EMAIL
# 0  11:10 AM  12:25 PM     4148    Song, M  songm@smccd.edu
# 2  11:10 AM  12:25 PM     4148    Song, M  songm@smccd.edu
# 4  11:10 AM  12:25 PM     4148    Song, M  songm@smccd.edu
# 6  12:10 PM   1:25 PM     7106    Guth, S  guths@smccd.edu
# 8  11:10 AM   1:25 PM     7106    Guth, S  guths@smccd.edu

# %%
courses_df = courses_df.reset_index()

# %%
courses_df.head()
# Out:
#    index    CRN Subject  COURSE                         TITLE COHORT TYPE  \
# 0      0  30151    BIOL     215            Organismal Biology    NaN  NaN
# 1      2  41373    BIOL     215            Organismal Biology    NaN  NaN
# 2      4  48398    BIOL     215            Organismal Biology    NaN  NaN
# 3      6  48537    BIOL     230  Introduction to Cell Biology    NaN  NaN
# 4      8  48811    BIOL     230  Introduction to Cell Biology    NaN  NaN
#
#   SCHEDULE   TIME IN  TIME OUT PLATFORM INSTRUCTOR INSTRUCTOR EMAIL
# 0     M, W  11:10 AM  12:25 PM     4148    Song, M  songm@smccd.edu
# 1     M, W  11:10 AM  12:25 PM     4148    Song, M  songm@smccd.edu
# 2     M, W  11:10 AM  12:25 PM     4148    Song, M  songm@smccd.edu
# 3     M, W  12:10 PM   1:25 PM     7106    Guth, S  guths@smccd.edu
# 4     M, W  11:10 AM   1:25 PM     7106    Guth, S  guths@smccd.edu

# %%
courses_df.to_csv("class_data clean.csv")
